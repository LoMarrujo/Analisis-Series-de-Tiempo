# %%
#pip install fredapi
#pip install seaborn

# %%
import yaml
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from fredapi import Fred

# %%
#  plot Style
plt.rcParams.update({'figure.figsize': (19, 6), 'figure.dpi': 200})
plt.style.use('seaborn-v0_8-dark-palette')
#  get api key from yaml
fred_api_key = yaml.safe_load(open("config/fred_api_key.yaml"))
#  call FRED with api key
fred = Fred(api_key=fred_api_key)

# %%
#  get SP500 data
df = {}
df['SP500'] = fred.get_series('SP500')
df = pd.DataFrame(df)

# %%
# Plot SP500
plt.plot(df.SP500, color='goldenrod')
plt.title('SP500')
plt.xlabel('Date')
plt.ylabel('Daily index value at market close')
# Out:
# Text(0, 0.5, 'Daily index value at market close')
